# %%
import numpy as np
import os
from PIL import Image
import matplotlib.pyplot as plt
import cv2

# %%
MAI_PATH = '../data/MAI_TRAIN'
LILY_PATH = '../data/LILY_TRAIN'
JACOB_PATH = '../data/JACOB_TEST_UNCROPPED'
AWAIS_PATH = '../AWAIS_TRAIN'
SWAROOP_PATH = '../SWAROOP_TRAIN'

NAME_800 = '800_AND_{}.png'
NAME_600 = '600_AND_{}.png'
NAME_ORG = 'NORMAL_AND_{}.png'

# %%
def crop_center(img,cropx,cropy):
    y,x,_ = img.shape
    startx = x//2-(cropx//2)
    starty = y//2-(cropy//2)    
    return img[starty:starty+cropy,startx:startx+cropx]

# %%
images = []
paths = [SWAROOP_PATH]
for path in paths:
    index = 0
    data = os.listdir(path)
    for file in data: 
        if not file.endswith('.jpeg'):
            continue
        img = Image.open(path + '/'+ file)
        img = np.array(img)
        new_img_800 = crop_center(img, 800, 800)
        new_img_600 = crop_center(img, 600, 600)
        plt.axis('off')
        plt.imshow(new_img_800)
        plt.savefig(NAME_800.format(index),bbox_inches='tight',transparent=True, pad_inches=0)
        plt.axis('off')
        plt.imshow(new_img_600)
        plt.savefig(NAME_600.format(index),bbox_inches='tight',transparent=True, pad_inches=0)
        plt.axis('off')
        plt.imshow(img)
        plt.savefig(NAME_ORG.format(index),bbox_inches='tight',transparent=True, pad_inches=0)
        index += 1
# Out:
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
